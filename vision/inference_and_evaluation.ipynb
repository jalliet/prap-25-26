# %% [markdown]
# ### Inference Testing for Various Weights

# %%
import os
from ultralytics import YOLO
import cv2

# %%
image = r"C:\Users\Kshitij Jha\OneDrive\Pictures\Camera Roll\WIN_20260225_16_56_21_Pro.jpg"
# image = cv2.imread(image_path)
# if image is None:
#     raise FileNotFoundError(f"Image not found: {image_path}")

# clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))

# def optimize_lighting(frame):
#     lab = cv2.cvtColor(frame, cv2.COLOR_BGR2LAB)
#     l_channel, a_channel, b_channel = cv2.split(lab)
#     cl = clahe.apply(l_channel)
#     merged_lab = cv2.merge((cl, a_channel, b_channel))
#     enhanced_bgr = cv2.cvtColor(merged_lab, cv2.COLOR_LAB2BGR)
#     return enhanced_bgr

# image = optimize_lighting(image)
# from matplotlib import pyplot as plt
# plt.figure(figsize=(10,6))
# plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
# plt.axis('off')

# %%
model = YOLO(model=r"D:\HDD Data\Computer Vision\yolov8_large_segment\runs\segment\train\weights\best.pt")

# %%
model_best = YOLO(model=r"D:\HDD Data\Computer Vision\final_models\best_large.pt")

# %%
model_last = YOLO(model=r"D:\HDD Data\Computer Vision\final_models\last_large.pt")

# %%
print(model.names)
target_classes = [1, 2, 3]
# Out:
# {0: 'Black', 1: 'Blue', 2: 'Red', 3: 'White'}

# %%
res = model.predict(source=image,
                      conf=0.65, iou=0.7, imgsz=1280,
                      save=True, device='cpu')
# Out:
# image 1/1 C:\Users\Kshitij Jha\OneDrive\Pictures\Camera Roll\WIN_20260225_16_56_21_Pro.jpg: 736x1280 3 Blues, 2 Reds, 3 Whites, 2446.5ms
# Speed: 12.0ms preprocess, 2446.5ms inference, 35.0ms postprocess per image at shape (1, 3, 736, 1280)
# Results saved to runs\segment\predict8

# %%
result_best = model_best.predict(source=image, 
                           conf=0.5, iou=0.6, imgsz=1280,
                           save=True, device='cpu')
# Out:
# image 1/1 C:\Users\Kshitij Jha\OneDrive\Pictures\Camera Roll\WIN_20260225_16_33_44_Pro.jpg: 736x1280 16 Blues, 9 Reds, 7 Whites, 2200.2ms
# Speed: 12.1ms preprocess, 2200.2ms inference, 79.9ms postprocess per image at shape (1, 3, 736, 1280)
# Results saved to runs\segment\predict8

# %%
# Not great
result_last = model_last.predict(source=image, 
                           conf=0.5, iou=0.6, imgsz=1280,
                           save=True, device='cpu')
# Out:
# image 1/1 C:\Users\Kshitij Jha\OneDrive\Pictures\Camera Roll\WIN_20260225_14_41_16_Pro.jpg: 736x1280 14 Blues, 9 Reds, 7 Whites, 2159.1ms
# Speed: 9.1ms preprocess, 2159.1ms inference, 65.6ms postprocess per image at shape (1, 3, 736, 1280)
# Results saved to runs\segment\predict9

# %% [markdown]
# ### Model XL

# %%
model_xl = YOLO(model=r"final_xl_model\best_xl.pt")
model_xl_last = YOLO(model=r"final_xl_model\last_xl.pt")

# %%
res_xl = model_xl.predict(source=image, 
                          conf=0.5, iou=0.6, imgsz=1280,
                          save=True, device='cpu')
# Out:
# image 1/1 C:\Users\Kshitij Jha\OneDrive\Pictures\Camera Roll\WIN_20260225_14_41_16_Pro.jpg: 736x1280 14 Blues, 9 Reds, 7 Whites, 3167.9ms
# Speed: 9.0ms preprocess, 3167.9ms inference, 71.6ms postprocess per image at shape (1, 3, 736, 1280)
# Results saved to runs\segment\predict6

# %%
res_last_xl = model_xl_last.predict(source=image,
                                    conf=0.5, iou=0.6, imgsz=1280,
                                    save=True, device='cpu')
# Out:
# image 1/1 C:\Users\Kshitij Jha\OneDrive\Pictures\Camera Roll\WIN_20260225_14_41_16_Pro.jpg: 736x1280 14 Blues, 9 Reds, 7 Whites, 3085.0ms
# Speed: 9.0ms preprocess, 3085.0ms inference, 72.6ms postprocess per image at shape (1, 3, 736, 1280)
# Results saved to runs\segment\predict10

# %%
xl_150epoch = YOLO(model=r"D:\HDD Data\Computer Vision\final_xl_model\xl_150epoch.pt")

# %%
res_150epoch = xl_150epoch.predict(source=image,
                                   conf=0.5, iou=0.6, imgsz=1280,
                                   save=True)
# Out:
# image 1/1 C:\Users\Kshitij Jha\OneDrive\Pictures\Camera Roll\WIN_20260225_14_24_39_Pro.jpg: 736x1280 4 Blues, 2 Reds, 1 White, 3311.0ms
# Speed: 15.3ms preprocess, 3311.0ms inference, 17.5ms postprocess per image at shape (1, 3, 736, 1280)
# Results saved to runs\segment\predict11

# %%
# 5 Blacks, 12 Blues, 4 Whites
